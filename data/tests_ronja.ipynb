# %%
import pandas as pd

# %%
# Read the CSV file with the correct delimiter
df = pd.read_csv('/home/ronja/documents/studium/bi-project/data/atp_matches_till_2022_preprocessed.csv', delimiter=',', low_memory=False)

# %%
print(df[df['winner_id'] == 200670 & df['year'] == 2022]['winner_match_ratio'].sum())
#print(df[df['loser_id'] == some_player_id & df['year'] == some_year]['loser_match_ratio'].sum())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_25999/1316832940.py in ?()
# ----> 1 print(df[df['winner_id'] == 200670 & df['year'] == 2022]['winner_match_ratio'].sum())
#       2 #print(df[df['loser_id'] == some_player_id & df['year'] == some_year]['loser_match_ratio'].sum())
#
# ~/virtualenv/daily/lib/python3.10/site-packages/pandas/core/generic.py in ?(self)
#    1574     @final
#    1575     def __nonzero__(self) -> NoReturn:
# -> 1576         raise ValueError(
#    1577             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1578             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1579         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df
# Out:
#                               tourney_id                     tourney_name  \
# 0                              1968-9343                     Bloemfontein
# 1                              1968-9343                     Bloemfontein
# 2                              1968-9343                     Bloemfontein
# 3                              1968-9343                     Bloemfontein
# 4                              1968-9343                     Bloemfontein
# ...                                  ...                              ...
# 1399182  2022-M-DC-2022-FLS-M-AUS-CRO-01  Davis Cup Finals SF: AUS vs CRO
# 1399183  2022-M-DC-2022-FLS-M-ITA-CAN-01  Davis Cup Finals SF: ITA vs CAN
# 1399184  2022-M-DC-2022-FLS-M-ITA-CAN-01  Davis Cup Finals SF: ITA vs CAN
# 1399185  2022-M-DC-2022-FLS-M-CAN-AUS-01   Davis Cup Finals F: CAN vs AUS
# 1399186  2022-M-DC-2022-FLS-M-CAN-AUS-01   Davis Cup Finals F: CAN vs AUS
#
#         surface  draw_size tourney_level tourney_date  match_num  winner_id  \
# 0          Hard         64             A   1968-01-08        269     110049
# 1          Hard         64             A   1968-01-08        269     110049
# 2          Hard         64             A   1968-01-08        250     100121
# 3          Hard         64             A   1968-01-08        250     100121
# 4          Hard         64             A   1968-01-08        250     100121
# ...         ...        ...           ...          ...        ...        ...
# 1399182    Hard          2             D   2022-11-25          2     200282
# 1399183    Hard          2             D   2022-11-26          1     132283
# 1399184    Hard          2             D   2022-11-26          2     200000
# 1399185    Hard          2             D   2022-11-27          1     133430
# 1399186    Hard          2             D   2022-11-27          2     200000
#
#          winner_seed winner_entry  ... l_SvGms l_bpSaved  l_bpFaced  \
# 0                NaN          NaN  ...     NaN       NaN        NaN
# 1                NaN          NaN  ...     NaN       NaN        NaN
# 2                NaN          NaN  ...     NaN       NaN        NaN
# 3                NaN          NaN  ...     NaN       NaN        NaN
# 4                NaN          NaN  ...     NaN       NaN        NaN
# ...              ...          ...  ...     ...       ...        ...
# 1399182          NaN          NaN  ...     NaN       NaN        NaN
# 1399183          NaN          NaN  ...     NaN       NaN        NaN
# 1399184          NaN          NaN  ...     NaN       NaN        NaN
# 1399185          NaN          NaN  ...     NaN       NaN        NaN
# 1399186          NaN          NaN  ...     NaN       NaN        NaN
#
#         winner_rank winner_rank_points  loser_rank  loser_rank_points  year  \
# 0               NaN                NaN         NaN                NaN  1968
# 1               NaN                NaN         NaN                NaN  1968
# 2               NaN                NaN         NaN                NaN  1968
# 3               NaN                NaN         NaN                NaN  1968
# 4               NaN                NaN         NaN                NaN  1968
# ...             ...                ...         ...                ...   ...
# 1399182        24.0             1790.0        17.0             2105.0  2022
# 1399183        45.0              950.0        18.0             2075.0  2022
# 1399184         6.0             4195.0        23.0             1865.0  2022
# 1399185        18.0             2075.0        95.0              592.0  2022
# 1399186         6.0             4195.0        24.0             1790.0  2022
#
#         winner_match_ratio loser_match_ratio
# 0                 0.166667          0.500000
# 1                 0.333333          0.500000
# 2                 0.018182          0.250000
# 3                 0.036364          0.250000
# 4                 0.054545          0.250000
# ...                    ...               ...
# 1399182           0.986111          1.000000
# 1399183           1.000000          0.983333
# 1399184           0.988506          1.000000
# 1399185           1.000000          1.000000
# 1399186           1.000000          1.000000
#
# [1399187 rows x 71 columns]
